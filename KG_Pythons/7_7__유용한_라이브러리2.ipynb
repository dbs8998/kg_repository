# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[1,9,5,7])
plt.show()

# %%
import matplotlib.pyplot as plt

#ro - 점으로 표현하기
plt.plot([1,2,3,4],[1,4,9,16], 'bo')
plt.axis([0,5,0,20])
plt.show()

# %%
import matplotlib.pyplot  as plt
plt.plot([1,2,3],[4,4,4], '-', color='C0', label='Solid')
plt.plot([1,2,3],[3,3,3], '--', color='C0', label='Dashed')
plt.plot([1,2,3],[2,2,2], ':', color='C0', label='Ditted')
plt.plot([1,2,3],[1,1,1], '-.', color='C0', label='Dash-dot')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8,3.2,0.5,5.0])
# plt.legend(loc='upper rigth', ncol=4)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#time : 0.2초마다
t = np.arange(0.,5.,0.2)

#다양한 색 & 라인 타입 : b,r,g --,s,^
plt.plot(t,t,'b--',t,t**2,'rs',t,t**3,'g^')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 생성
x = np.linspace(0, 10, 120)  
# 0부터 10까지 120개의 균일한 값 생성

y = 2 + 1 * np.sin(2 * x)    
# 사인 함수 변형: 진폭=1, 주기=pi, y축 이동=+2

x2 = np.linspace(0, 10, 25)  
# 0부터 10까지 25개의 값 (표식용으로 적은 개수)

y2 = 2 + 1 * np.sin(2 * x2)  
# 같은 함수이지만 x2 포인트에 대응하는 y2

# plot
fig, ax = plt.subplots()  
# 새로운 figure와 하나의 axes(좌표축) 생성
# - fig : 전체 그림
# - ax : 실제 그리는 좌표 영역

# 선 + 마커
ax.plot(x2, y2 + 2.5, 'ro-', markeredgewidth=2)
# 빨간색(r) 원형(o) 마커 + 선(-)
# y2를 위로 2.5 이동 (y축 위치 변경)
# markeredgewidth=2 : 마커 테두리 두께 설정

# 부드러운 곡선
ax.plot(x, y, linewidth=2.0)
# 세밀한 x로 부드러운 사인 곡선
# linewidth=2.0 : 선 두께

# 교차 마커만
ax.plot(x2, y2 - 2.5, 'gx', linewidth=2)
# 초록색(g) X 마커
# y2를 아래로 2.5 이동

# 축 범위와 눈금 설정
ax.set(
    xlim=(0, 8),                    # x축 범위 0~8
    xticks=np.arange(0, 8),         # x축 눈금 위치 (0,1,2,...7)
    ylim=(-2, 6),                   # y축 범위 -2~6
    yticks=np.arange(-2, 6)         # y축 눈금 위치 (-2,-1,...5)
)

plt.show()
# 그림 출력

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0,5.0,0.5)
t2 = np.arange(0.0,5.0,0.05)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'yo', t2, f(t2), 'k')
plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'g--')
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3]
y=[2,3,4]

plt.plot(x,y,'r')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3],y[1:3], alpha=0.2)
#alpha : 투명도
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(5)
y = ['1', '2', '3','4', '5']


val = [10,2,-5,3, -12]

# 1️⃣ 색상 리스트 만들기
colors = ['blue' if v >= 0 else 'red' for v in val]

# 2️⃣ 막대그래프 그리기
plt.bar(x, val, color=colors)

# plt.bar(x, val)
plt.xticks(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


np.random.seed(43)
x = 4 + np.random.normal(0,2,24)
y = 4 + np.random.normal(0,2,len(x))

sizes = np.random.uniform(15,80,len(x))
colors = np.random.uniform(15,80,len(x))

fig, ax = plt.subplots()

ax.scatter(x,y,s=sizes, c=colors,vmin=0,vmax=100)

ax.set(xlim=(0,8), xticks=np.arange(1,8),
       ylim=(0,8), yticks=np.arange(1,8))

# %%
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

img_path = 'example1.jpg'

try:

    img = np.asarray(Image.open(img_path))
    print(repr(img))

    imgplot = plt.imshow(img)
    img.shape

except FileNotFoundError:
    print("Error : 파일을 찾을 수 없습니다.")

# %%
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

img_path = 'example1.jpg'

try:

    img = np.asarray(Image.open(img_path))
    lum_img = img[:,:,0]
    imgplot = plt.imshow(lum_img)
    plt.colorbar()
    img.shape

except FileNotFoundError:
    print("Error : 파일을 찾을 수 없습니다.")

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(5)



val = [30, 15, 25, 25, 9, 40, 5]

explodes = (0, 0.1, 0, 0, 0,0, 0)  # 두 번째 조각만 강조

# 1️⃣ 색상 리스트 만들기
colors = ['blue' if v >= 20 else 'red' for v in val]
plt.pie(val,colors=colors,explode=explodes)

plt.show()

# %%
import threading
import time

def print_numbers():
    for i in range(5):
        print(i)
        time.sleep(1)

#스레드 생성
threed = threading.Thread(target=print_numbers)

#스레드 시작
threed.start()

#메인 스레드에서 작업
for i in range(5,10):
    print(i)
    time.sleep(1)


threed.join()
print("스레드 종료")

# %%
import threading as th
import time


def print_numbers(thread_name, delay):
    for i in range(5):
        print(f"{thread_name}: {i}")
        time.sleep(delay)


#스레드 생성
threed1 = th.Thread(target=print_numbers, args=("Threed-1", 1))
threed2 = th.Thread(target=print_numbers, args=("Threed-2", 1.5))

#스레드 시작
threed1.start()
threed2.start()

#스레드 종료될때까지 대기
threed1.join()
threed2.join()
print("종료")

# %%
import threading as th

shared_counter= 0

lock = threading.Lock()

def increment_counter(thread_name):
    global shared_counter
    for _ in range(100000):
        #Lock 획득
        lock.acquire()
        try:
            shared_counter += 1
        finally:
            lock.release()
    print(f"{thread_name} 완료")

#스레드 생성
threed1 = th.Thread(target=increment_counter, args=("Threed-1", ))
threed2 = th.Thread(target=increment_counter, args=("Threed-2", ))

#스레드 시작
threed1.start()
threed2.start()

#스레드 종료될때까지 대기
threed1.join()
threed2.join()
print("최종 카운터 값 :", shared_counter)

# %%
import threading
import time
import queue

q = queue.Queue()

def producer():
    for i in range(5):
        q.put(i)
        print(f"생산자 : {i} 생성")
        time.sleep(1)

def consumer():
    while True:
        item = q.get()
        if item is None:
            break
        print(f"소비자 : {item} 소비")
        time.sleep(2)

#스레드 생성
producer_thread = threading.Thread(target=producer)
consumer_thread = threading.Thread(target=consumer)

producer_thread.start()
consumer_thread.start()

producer_thread.join()

q.put(None)

consumer_thread.join()
print("모든 스레드 종료")

# %%
#응용실습1
import matplotlib.pyplot as plt
import numpy as np

# [색상][마커][선스타일]
# 예: 'bo-'
# b : blue
# o : circle marker
# - : solid line

x = np.arange(4)
val = [3,8,1,10]
plt.plot(val,'bo-')
# plt.plot(x, val,'bo-')

plt.show()

# %%
#응용실습2
import matplotlib.pyplot as plt
import numpy as np

# [색상][마커][선스타일]
# 실선	'-'	기본 연속선
# 점선	':'	작은 점으로 된 선
# 대시선	'--'	긴 점선
# 대시점선	'-.'	대시 + 점 섞인 선

x = np.arange(4)
val = [3,8,1,10]
plt.plot(val,'b:')
# plt.plot(x, val,'bo-')

plt.show()

# %%
#응용실습3 - grid()
import matplotlib.pyplot as plt
import numpy as np

# True/False	grid on/off	plt.grid(True)
# which	'major', 'minor', 'both'	plt.grid(which='both')
# axis	'x', 'y', 'both' (격자선 방향)	plt.grid(axis='y')
# color	선 색상	plt.grid(color='gray')
# linestyle	선 스타일 ('-', '--', '-.', ':')	plt.grid(linestyle='--')
# linewidth	선 두께	plt.grid(linewidth=0.5)
# alpha	투명도 (0~1)	plt.grid(alpha=0.7)

# 예시
# plt.grid(
#     color='gray',         # 색상
#     linestyle='--',       # 대시선
#     linewidth=0.7,        # 두께
#     alpha=0.5             # 투명도
#     axis='x'              # x축만 나오기
# )

x = np.arange(4)
val = [3,8,1,10]
plt.plot(val,'b:')
plt.grid()
# plt.plot(x, val,'bo-')

plt.show()

# %%
#응용실습4 - subplot()
# subplot() 은 하나의 Figure(그림)에 여러 개의 Axes(그래프 영역)를 나누어 그리는 기능
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(4)
val = [3,8,1,10]
val2 = [10,20,30,40]

plt.figure(1)
plt.subplot(121)
plt.plot(val,'b')
plt.subplot(122)
plt.plot(val2,'b')

plt.show()

# %%
#응용실습5 - subplot()
# subplot() 은 하나의 Figure(그림)에 여러 개의 Axes(그래프 영역)를 나누어 그리는 기능
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(4)
val = [3,8,1,10]
val2 = [10,20,30,40]

plt.figure(1)
plt.subplot(231)
plt.plot(val,'b')
plt.subplot(232)
plt.plot(val2,'b')
plt.subplot(233)
plt.plot(val2,'b')


plt.subplot(234)
plt.plot(val,'b')
plt.subplot(235)
plt.plot(val2,'b')
plt.subplot(236)
plt.plot(val2,'b')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as mp

#산점도(Scatter plot) 를 그리는 함수.
# 개별 데이터 포인트를 점으로 시각화할 때 사용

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])


fig, ax = plt.subplots()

ax.scatter(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as mp

#산점도(Scatter plot) 를 그리는 함수.
# 개별 데이터 포인트를 점으로 시각화할 때 사용

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])

colors = np.random.uniform(1,100,len(x))

fig, ax = plt.subplots()

ax.scatter(x, y, c=colors)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1️⃣ 스크래핑
url = 'https://finance.naver.com/sise/sise_index_day.nhn?code=KOSPI&page=1'
headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# 2️⃣ 테이블 추출
table = soup.select_one('table.type_1')
dfs = pd.read_html(str(table))
df = dfs[0]

# 3️⃣ 컬럼명 클린
df.columns = df.columns.str.strip()
print("컬럼명:", df.columns)

# 4️⃣ 유효 행만
df = df.dropna()

# 5️⃣ 필요한 컬럼만
df = df[['날짜', '체결가']]
df = df.rename(columns={'날짜': 'Date', '체결가': 'Close'})

# 6️⃣ 데이터 변환
df['Date'] = pd.to_datetime(df['Date'], format='%Y.%m.%d')
df['Close'] = df['Close'].astype(str).str.replace(',', '').astype(float)

# 7️⃣ 날짜 순 정렬
df = df.sort_values('Date')
print(df.head())

# 8️⃣ NumPy 변환
dates = df['Date'].to_numpy()
prices = df['Close'].to_numpy()

# 9️⃣ 시각화
plt.figure(figsize=(10, 5))
plt.plot(dates, prices, 'bo-', label='KOSPI Close')
plt.title('KOSPI Closing Price (체결가)')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 목표: 기본 plot() 함수로 선과 마커를 같이 그리기

# ✅ 아래 데이터를 이용해:

# ini
# 복사
# 편집
# x = [0, 1, 2, 3, 4]
# y = [2, 5, 3, 8, 7]
# ✅ 다음 조건으로 플롯을 그려라:

# 파란색 실선

# 원형 마커

# 선 두께 2

# 마커 크기 8

# 격자(grid) 추가 (기본 옵션)

import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [2, 5, 3, 8, 7]

plt.plot(x, y, 'bo-', linewidth=2, markeredgewidth=8)
plt.grid()

plt.show()

# %%
# 목표: 하나의 figure 안에 여러 선 그래프 배치

# ✅ 아래 데이터 사용:

# ini
# 복사
# 편집
# x = [1, 2, 3, 4]
# y1 = [10, 20, 15, 25]
# y2 = [8, 17, 14, 20]
# ✅ 요구:

# 하나의 figure에 subplot 2개

# 위쪽: y1을 파란색 실선('-')

# 아래쪽: y2를 초록색 점선(':')

# 두 플롯 모두:

# 축 라벨 추가 (X-Axis, Y-Axis)

# 격자선 추가 (linestyle은 '--', color='gray', alpha=0.5)

# plt.subplot() 사용

# 선 스타일

# grid() 옵션 상세
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y1 = [10, 20, 15, 25]
y2 = [8, 17, 14, 20]


plt.figure(1)
plt.subplot(211)
plt.plot(x, y1, 'b-')
plt.grid('--', color='gray', alpha=0.5)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')


plt.subplot(212)
plt.plot(x, y2, 'g:')
plt.grid('--', color='gray', alpha=0.5)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %%
import numpy as np

arr1 = np.array([1,2,3])
arr2 = np.array([4,5,6])

arr = np.append(arr1, arr2)
print(arr)

# %%
# 목표: 하나의 코드에서 다양한 차트를 그리기


# ✅ 조건:

# 각 그래프를 plt.figure()로 나누어 따로 출력

# 각 차트마다 제목(title) 추가

# ⭐️ 테스트하는 스킬:

# scatter() 색상/크기/컬러맵

# plt.bar() 색상 조건부 지정

# plt.pie() explode/label/color

# plt.figure(), plt.title()



# ✅ 요구:

# 1️⃣ Scatter Plot

# 랜덤하게 20개의 x, y 데이터 생성 (np.random.uniform)

# 마커 색상을 값에 따라 컬러맵 사용 (c=colors, cmap='viridis')


import matplotlib.pyplot as plt
import numpy as np

#Scatter Plot
sc_x = np.random.uniform(1, 20, 20)
sc_y = np.random.uniform(1, 20, 20)

colors = np.random.uniform(15,80,len(sc_x))
plt.figure(1)
sc = plt.scatter(sc_x, sc_y, c=colors, cmap='viridis')
plt.title("Scatter Plot")

plt.colorbar(sc)

# colorbar 추가

# 2️⃣ Bar Chart

# x = np.arange(5)

# val = [10, -5, 12, -8, 7]

# 양수는 파란색, 음수는 빨간색

plt.figure(2)
x = np.arange(5)
val = [10, -5, 12, -8, 7]

colors = ['blue' if v >= 0 else 'red' for v in val]
plt.title("Bar Chart")

plt.bar(x, val, color=colors)


# 3️⃣ Pie Chart

# val2 = [30, 20, 25, 25]

# 두 번째 조각만 explode=0.1

# 각 조각별 색상: ['red','blue','green','orange']
plt.figure(3)
val2 = [30, 20, 25, 25]
col = ['red','blue','green','orange']
explode = [0,0.1,0,0]
plt.title("Pie Chart")

plt.pie(val2,explode=explode, colors=col)

# %%
import numpy as np

arr = np.array([1,2,3,4,5,4,4])

# 값이 4인 인덱스 찾기
index = np.where(arr == 4)

print(index[0].tolist())

# %%
import numpy as np

arr = np.array([41,42,43,44])

x = [True, False, True, False]

result = arr[x]

print(result)

# %%
import pandas as pd

url = 'https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)'
tables = pd.read_html(url)

# 위키피디아 구조상 2번째 또는 3번째 테이블에 국가별 GDP가 있음
df = tables[2]
print("원래 컬럼 (MultiIndex):")
print(df.columns)

# 1️⃣ 컬럼 이름 평평하게 만들기
df.columns = ['_'.join(col).strip() for col in df.columns.values]
print("\n플랫 컬럼명:")
print(df.columns)

# 2️⃣ Country 컬럼 이름 확인
country_col = [col for col in df.columns if 'Country' in col][0]
print("\nCountry 컬럼명:", country_col)

# 3️⃣ 한국 필터링
korea_df = df[df[country_col].str.contains('Korea', case=False)]
print("\n한국 데이터:")
print(korea_df)
